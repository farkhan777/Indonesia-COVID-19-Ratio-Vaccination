# %%
# !pip install -q kaggle

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-3d412dfa-5cca-4411-9593-699c24f90093" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d412dfa-5cca-4411-9593-699c24f90093">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"farhanhamzah","key":"eb51f66ce1088b24ad1d5a4dab424e33"}'}

# %%
! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d sinakaraji/covid-vaccination-vs-death
# Out:
# Downloading covid-vaccination-vs-death.zip to /content
#   0% 0.00/705k [00:00<?, ?B/s]
# 100% 705k/705k [00:00<00:00, 43.9MB/s]

# %%
import os
import zipfile
# Import all required libraries
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

# Importing layers from keras. Use LSTM for input layer, and Dense for hidden and output layer
from keras.layers import Dense, LSTM, Dropout, Bidirectional 
from keras.models import Sequential

# Import SGD Optimizers
from tensorflow.keras.optimizers import SGD

# Import for splitting test and training data set
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
local_zip = '/content/covid-vaccination-vs-death.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
df = pd.read_csv('/content/covid-vaccination-vs-death_ratio.csv')

# %%
df
# Out:
#        Unnamed: 0      country iso_code  ... New_deaths  population      ratio
# 0               0  Afghanistan      AFG  ...         12  40194523.0   1.116764
# 1               1  Afghanistan      AFG  ...         10  40194523.0   1.170162
# 2               2  Afghanistan      AFG  ...         10  40194523.0   1.185154
# 3               3  Afghanistan      AFG  ...         19  40194523.0   1.192630
# 4               4  Afghanistan      AFG  ...         14  40194523.0   1.193133
# ...           ...          ...      ...  ...        ...         ...        ...
# 24174       24174     Zimbabwe      ZWE  ...          1  15183882.0  22.946747
# 24175       24175     Zimbabwe      ZWE  ...          0  15183882.0  23.150470
# 24176       24176     Zimbabwe      ZWE  ...          1  15183882.0  23.599077
# 24177       24177     Zimbabwe      ZWE  ...          0  15183882.0  23.875456
# 24178       24178     Zimbabwe      ZWE  ...          0  15183882.0  24.050635
#
# [24179 rows x 10 columns]

# %%
#define values
indonesia = ["Indonesia"]

#drop rows that contain any value in the list
df = df[df.country.isin(indonesia) == True]
df
# Out:
#       Unnamed: 0    country iso_code  ... New_deaths   population      ratio
# 9680        9680  Indonesia      IDN  ...        476  277477532.0   0.132738
# 9681        9681  Indonesia      IDN  ...        187  277477532.0   0.145962
# 9682        9682  Indonesia      IDN  ...        210  277477532.0   0.173760
# 9683        9683  Indonesia      IDN  ...        270  277477532.0   0.177720
# 9684        9684  Indonesia      IDN  ...        279  277477532.0   0.194442
# ...          ...        ...      ...  ...        ...          ...        ...
# 9937        9937  Indonesia      IDN  ...         15  277477532.0  47.316577
# 9938        9938  Indonesia      IDN  ...         13  277477532.0  47.573717
# 9939        9939  Indonesia      IDN  ...         11  277477532.0  47.598083
# 9940        9940  Indonesia      IDN  ...          5  277477532.0  48.076704
# 9941        9941  Indonesia      IDN  ...         14  277477532.0  48.301211
#
# [262 rows x 10 columns]

# %%
#Convert Data Types
df['date'] = pd.to_datetime(df['date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 9680 to 9941
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               262 non-null    int64
#  1   country                  262 non-null    object
#  2   iso_code                 262 non-null    object
#  3   date                     262 non-null    datetime64[ns]
#  4   total_vaccinations       262 non-null    float64
#  5   people_vaccinated        262 non-null    float64
#  6   people_fully_vaccinated  262 non-null    float64
#  7   New_deaths               262 non-null    int64
#  8   population               262 non-null    float64
#  9   ratio                    262 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(2)
# memory usage: 22.5+ KB

# %%
# Print banyaknya vaksinasi di seluruh area Jawa Timur dari waktu ke waktu 
data_graph = df.groupby(['date', 'country'])['ratio'].max().reset_index()
data_graph.sort_values(by="date")

data_graph['date'] = pd.to_datetime(data_graph['date'])
data_graph
# Out:
#           date    country      ratio
# 0   2021-01-28  Indonesia   0.132738
# 1   2021-01-29  Indonesia   0.145962
# 2   2021-01-30  Indonesia   0.173760
# 3   2021-01-31  Indonesia   0.177720
# 4   2021-02-01  Indonesia   0.194442
# ..         ...        ...        ...
# 257 2021-11-16  Indonesia  47.316577
# 258 2021-11-17  Indonesia  47.573717
# 259 2021-11-18  Indonesia  47.598083
# 260 2021-11-19  Indonesia  48.076704
# 261 2021-11-20  Indonesia  48.301211
#
# [262 rows x 3 columns]

# %%
sorted_data_graph = data_graph.sort_values(by ='date',ascending=True)

plt.figure(figsize=(20,10))
sns.lineplot(x="date", y="ratio", data=sorted_data_graph, hue='country')
plt.title('Persebaran rasio vaksinasi dengan jumlah penduduk negara Indonesia tahun 2021',fontsize=15);

# %%
minMAE = (sorted_data_graph['ratio'].max() - sorted_data_graph['ratio'].min()) * (10/100)
minMAE
# Out:
# 4.816847333066232

# %%
#Variables for training
cols = list(sorted_data_graph)[2:7]

df_cols = sorted_data_graph[cols].astype(float)

# %%
#LSTM used sigmoid and tanh that are sensitive to magnitude so values need to be normalized
#normalize the dataset
scaler = StandardScaler()
scaler = scaler.fit(df_cols)
df_cols_scaled = scaler.transform(df_cols)

# %%
dates = sorted_data_graph['date'].values
ratio = sorted_data_graph['ratio'].values

# %%
dates = np.asarray(dates).astype('float32')
ratio = np.asarray(ratio).astype('float32')

# %%
#As required for LSTM networks, require to reshape an input data into n_samples x timesteps
#In this example, the n_features is 2. I will make timesteps = 3
#With this, the resultant n_samples is 5 (as the input data has 9 rows)
trainX = []
trainY = []

n_future = 1 #Number of days I want to predict into the future
n_past = 14 # Number of past days I want to use to predict the future


for i in range(n_past, len(df_cols_scaled) - n_future+1):
  trainX.append(df_cols_scaled[i - n_past:i, 0:df_cols.shape[1]])
  trainY.append(df_cols_scaled[i + n_future - 1:i + n_future,0])

trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape)) #holding 14 days that are looking back and 5 variables that we got
print('trainY shape == {}.'.format(trainY.shape)) # 1 is the day after n_past
# Out:
# trainX shape == (248, 14, 1).
# trainY shape == (248, 1).

# %%
 model = tf.keras.models.Sequential([
                                     tf.keras.layers.LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True),
                                     tf.keras.layers.LSTM(32, activation='relu', return_sequences=False),
                                     tf.keras.layers.Dropout(0.2),
                                     tf.keras.layers.Dense(32, activation="relu"),
                                     tf.keras.layers.Dense(trainY.shape[1])    
                                   ])
 
optimizer = tf.keras.optimizers.SGD(lr=1.0000e-04, momentum=0.9)

model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
  
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 14, 64)            16896
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 30,401
# Trainable params: 30,401
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
#Membuat fungsi callback
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('mae')<0.1):
      print("\nmae kurang dari 10%")
      self.model.stop_training = True
callbacks = myCallback()

# %%
#Training Model
history = model.fit(trainX, trainY, batch_size=16, validation_split=0.2, epochs=400, verbose=2, callbacks=[callbacks])
# Out:
# Epoch 1/400
# 13/13 - 6s - loss: 0.2608 - mae: 0.6353 - val_loss: 1.1121 - val_mae: 1.6121 - 6s/epoch - 429ms/step
# Epoch 2/400
# 13/13 - 1s - loss: 0.2591 - mae: 0.6334 - val_loss: 1.1162 - val_mae: 1.6162 - 987ms/epoch - 76ms/step
# Epoch 3/400
# 13/13 - 1s - loss: 0.2556 - mae: 0.6291 - val_loss: 1.1202 - val_mae: 1.6202 - 1s/epoch - 90ms/step
# Epoch 4/400
# 13/13 - 1s - loss: 0.2527 - mae: 0.6256 - val_loss: 1.1245 - val_mae: 1.6245 - 1s/epoch - 100ms/step
# Epoch 5/400
# 13/13 - 1s - loss: 0.2514 - mae: 0.6240 - val_loss: 1.1291 - val_mae: 1.6291 - 1s/epoch - 95ms/step
# Epoch 6/400
# 13/13 - 1s - loss: 0.2481 - mae: 0.6202 - val_loss: 1.1327 - val_mae: 1.6327 - 877ms/epoch - 67ms/step
# Epoch 7/400
# 13/13 - 1s - loss: 0.2457 - mae: 0.6174 - val_loss: 1.1369 - val_mae: 1.6369 - 919ms/epoch - 71ms/step
# Epoch 8/400
# 13/13 - 1s - loss: 0.2439 - mae: 0.6151 - val_loss: 1.1407 - val_mae: 1.6407 - 892ms/epoch - 69ms/step
# Epoch 9/400
# 13/13 - 1s - loss: 0.2425 - mae: 0.6134 - val_loss: 1.1443 - val_mae: 1.6443 - 912ms/epoch - 70ms/step
# Epoch 10/400
# 13/13 - 1s - loss: 0.2404 - mae: 0.6107 - val_loss: 1.1477 - val_mae: 1.6477 - 917ms/epoch - 71ms/step
# Epoch 11/400
# 13/13 - 1s - loss: 0.2378 - mae: 0.6077 - val_loss: 1.1514 - val_mae: 1.6514 - 1s/epoch - 81ms/step
# Epoch 12/400
# 13/13 - 1s - loss: 0.2367 - mae: 0.6065 - val_loss: 1.1553 - val_mae: 1.6553 - 902ms/epoch - 69ms/step
# Epoch 13/400
# 13/13 - 1s - loss: 0.2344 - mae: 0.6033 - val_loss: 1.1588 - val_mae: 1.6588 - 919ms/epoch - 71ms/step
# Epoch 14/400
# 13/13 - 1s - loss: 0.2318 - mae: 0.6005 - val_loss: 1.1621 - val_mae: 1.6621 - 1s/epoch - 77ms/step
# Epoch 15/400
# 13/13 - 1s - loss: 0.2300 - mae: 0.5987 - val_loss: 1.1655 - val_mae: 1.6655 - 1s/epoch - 81ms/step
# Epoch 16/400
# 13/13 - 1s - loss: 0.2279 - mae: 0.5958 - val_loss: 1.1689 - val_mae: 1.6689 - 1s/epoch - 79ms/step
# Epoch 17/400
# 13/13 - 1s - loss: 0.2261 - mae: 0.5936 - val_loss: 1.1722 - val_mae: 1.6722 - 982ms/epoch - 76ms/step
# Epoch 18/400
# 13/13 - 1s - loss: 0.2230 - mae: 0.5900 - val_loss: 1.1759 - val_mae: 1.6759 - 919ms/epoch - 71ms/step
# Epoch 19/400
# 13/13 - 1s - loss: 0.2225 - mae: 0.5893 - val_loss: 1.1792 - val_mae: 1.6792 - 987ms/epoch - 76ms/step
# Epoch 20/400
# 13/13 - 1s - loss: 0.2194 - mae: 0.5857 - val_loss: 1.1822 - val_mae: 1.6822 - 1s/epoch - 80ms/step
# Epoch 21/400
# 13/13 - 1s - loss: 0.2185 - mae: 0.5847 - val_loss: 1.1850 - val_mae: 1.6850 - 1s/epoch - 77ms/step
# Epoch 22/400
# 13/13 - 1s - loss: 0.2152 - mae: 0.5806 - val_loss: 1.1878 - val_mae: 1.6878 - 873ms/epoch - 67ms/step
# Epoch 23/400
# 13/13 - 1s - loss: 0.2147 - mae: 0.5794 - val_loss: 1.1905 - val_mae: 1.6905 - 1s/epoch - 85ms/step
# Epoch 24/400
# 13/13 - 1s - loss: 0.2132 - mae: 0.5776 - val_loss: 1.1929 - val_mae: 1.6929 - 1s/epoch - 86ms/step
# Epoch 25/400
# 13/13 - 1s - loss: 0.2112 - mae: 0.5758 - val_loss: 1.1958 - val_mae: 1.6958 - 919ms/epoch - 71ms/step
# Epoch 26/400
# 13/13 - 1s - loss: 0.2078 - mae: 0.5706 - val_loss: 1.1983 - val_mae: 1.6983 - 1s/epoch - 82ms/step
# Epoch 27/400
# 13/13 - 1s - loss: 0.2052 - mae: 0.5678 - val_loss: 1.2008 - val_mae: 1.7008 - 995ms/epoch - 77ms/step
# Epoch 28/400
# 13/13 - 1s - loss: 0.2052 - mae: 0.5676 - val_loss: 1.2028 - val_mae: 1.7028 - 919ms/epoch - 71ms/step
# Epoch 29/400
# 13/13 - 1s - loss: 0.2044 - mae: 0.5664 - val_loss: 1.2053 - val_mae: 1.7053 - 922ms/epoch - 71ms/step
# Epoch 30/400
# 13/13 - 1s - loss: 0.2016 - mae: 0.5627 - val_loss: 1.2068 - val_mae: 1.7068 - 1s/epoch - 80ms/step
# Epoch 31/400
# 13/13 - 1s - loss: 0.2017 - mae: 0.5631 - val_loss: 1.2091 - val_mae: 1.7091 - 1s/epoch - 100ms/step
# Epoch 32/400
# 13/13 - 1s - loss: 0.1982 - mae: 0.5584 - val_loss: 1.2106 - val_mae: 1.7106 - 1s/epoch - 90ms/step
# Epoch 33/400
# 13/13 - 1s - loss: 0.1966 - mae: 0.5564 - val_loss: 1.2125 - val_mae: 1.7125 - 883ms/epoch - 68ms/step
# Epoch 34/400
# 13/13 - 1s - loss: 0.1965 - mae: 0.5571 - val_loss: 1.2144 - val_mae: 1.7144 - 950ms/epoch - 73ms/step
# Epoch 35/400
# 13/13 - 1s - loss: 0.1924 - mae: 0.5510 - val_loss: 1.2160 - val_mae: 1.7160 - 929ms/epoch - 71ms/step
# Epoch 36/400
# 13/13 - 1s - loss: 0.1925 - mae: 0.5509 - val_loss: 1.2173 - val_mae: 1.7173 - 919ms/epoch - 71ms/step
# Epoch 37/400
# 13/13 - 1s - loss: 0.1907 - mae: 0.5487 - val_loss: 1.2192 - val_mae: 1.7192 - 1s/epoch - 86ms/step
# Epoch 38/400
# 13/13 - 1s - loss: 0.1885 - mae: 0.5458 - val_loss: 1.2206 - val_mae: 1.7206 - 907ms/epoch - 70ms/step
# Epoch 39/400
# 13/13 - 1s - loss: 0.1896 - mae: 0.5465 - val_loss: 1.2211 - val_mae: 1.7211 - 907ms/epoch - 70ms/step
# Epoch 40/400
# 13/13 - 1s - loss: 0.1866 - mae: 0.5436 - val_loss: 1.2222 - val_mae: 1.7222 - 973ms/epoch - 75ms/step
# Epoch 41/400
# 13/13 - 1s - loss: 0.1872 - mae: 0.5438 - val_loss: 1.2233 - val_mae: 1.7233 - 920ms/epoch - 71ms/step
# Epoch 42/400
# 13/13 - 1s - loss: 0.1841 - mae: 0.5389 - val_loss: 1.2247 - val_mae: 1.7247 - 1s/epoch - 85ms/step
# Epoch 43/400
# 13/13 - 1s - loss: 0.1825 - mae: 0.5368 - val_loss: 1.2258 - val_mae: 1.7258 - 972ms/epoch - 75ms/step
# Epoch 44/400
# 13/13 - 1s - loss: 0.1831 - mae: 0.5370 - val_loss: 1.2262 - val_mae: 1.7262 - 942ms/epoch - 72ms/step
# Epoch 45/400
# 13/13 - 1s - loss: 0.1794 - mae: 0.5329 - val_loss: 1.2271 - val_mae: 1.7271 - 1s/epoch - 85ms/step
# Epoch 46/400
# 13/13 - 1s - loss: 0.1793 - mae: 0.5304 - val_loss: 1.2277 - val_mae: 1.7277 - 1s/epoch - 77ms/step
# Epoch 47/400
# 13/13 - 1s - loss: 0.1807 - mae: 0.5337 - val_loss: 1.2286 - val_mae: 1.7286 - 1s/epoch - 83ms/step
# Epoch 48/400
# 13/13 - 1s - loss: 0.1785 - mae: 0.5293 - val_loss: 1.2293 - val_mae: 1.7293 - 973ms/epoch - 75ms/step
# Epoch 49/400
# 13/13 - 1s - loss: 0.1754 - mae: 0.5254 - val_loss: 1.2294 - val_mae: 1.7294 - 1s/epoch - 96ms/step
# Epoch 50/400
# 13/13 - 1s - loss: 0.1740 - mae: 0.5233 - val_loss: 1.2300 - val_mae: 1.7300 - 908ms/epoch - 70ms/step
# Epoch 51/400
# 13/13 - 1s - loss: 0.1729 - mae: 0.5205 - val_loss: 1.2299 - val_mae: 1.7299 - 917ms/epoch - 71ms/step
# Epoch 52/400
# 13/13 - 1s - loss: 0.1751 - mae: 0.5225 - val_loss: 1.2302 - val_mae: 1.7302 - 1s/epoch - 78ms/step
# Epoch 53/400
# 13/13 - 1s - loss: 0.1696 - mae: 0.5153 - val_loss: 1.2304 - val_mae: 1.7304 - 980ms/epoch - 75ms/step
# Epoch 54/400
# 13/13 - 1s - loss: 0.1707 - mae: 0.5183 - val_loss: 1.2306 - val_mae: 1.7306 - 1s/epoch - 82ms/step
# Epoch 55/400
# 13/13 - 1s - loss: 0.1678 - mae: 0.5135 - val_loss: 1.2312 - val_mae: 1.7312 - 977ms/epoch - 75ms/step
# Epoch 56/400
# 13/13 - 1s - loss: 0.1669 - mae: 0.5100 - val_loss: 1.2311 - val_mae: 1.7311 - 972ms/epoch - 75ms/step
# Epoch 57/400
# 13/13 - 1s - loss: 0.1687 - mae: 0.5119 - val_loss: 1.2312 - val_mae: 1.7312 - 926ms/epoch - 71ms/step
# Epoch 58/400
# 13/13 - 1s - loss: 0.1697 - mae: 0.5152 - val_loss: 1.2312 - val_mae: 1.7312 - 903ms/epoch - 69ms/step
# Epoch 59/400
# 13/13 - 1s - loss: 0.1689 - mae: 0.5151 - val_loss: 1.2315 - val_mae: 1.7315 - 1s/epoch - 86ms/step
# Epoch 60/400
# 13/13 - 1s - loss: 0.1663 - mae: 0.5083 - val_loss: 1.2314 - val_mae: 1.7314 - 903ms/epoch - 69ms/step
# Epoch 61/400
# 13/13 - 1s - loss: 0.1665 - mae: 0.5098 - val_loss: 1.2316 - val_mae: 1.7316 - 955ms/epoch - 73ms/step
# Epoch 62/400
# 13/13 - 1s - loss: 0.1664 - mae: 0.5093 - val_loss: 1.2310 - val_mae: 1.7310 - 1s/epoch - 78ms/step
# Epoch 63/400
# 13/13 - 1s - loss: 0.1611 - mae: 0.5011 - val_loss: 1.2304 - val_mae: 1.7304 - 991ms/epoch - 76ms/step
# Epoch 64/400
# 13/13 - 1s - loss: 0.1628 - mae: 0.5021 - val_loss: 1.2302 - val_mae: 1.7302 - 926ms/epoch - 71ms/step
# Epoch 65/400
# 13/13 - 1s - loss: 0.1617 - mae: 0.5025 - val_loss: 1.2295 - val_mae: 1.7295 - 920ms/epoch - 71ms/step
# Epoch 66/400
# 13/13 - 1s - loss: 0.1615 - mae: 0.5010 - val_loss: 1.2291 - val_mae: 1.7291 - 1s/epoch - 93ms/step
# Epoch 67/400
# 13/13 - 1s - loss: 0.1574 - mae: 0.4953 - val_loss: 1.2288 - val_mae: 1.7288 - 1s/epoch - 92ms/step
# Epoch 68/400
# 13/13 - 1s - loss: 0.1602 - mae: 0.4978 - val_loss: 1.2283 - val_mae: 1.7283 - 946ms/epoch - 73ms/step
# Epoch 69/400
# 13/13 - 1s - loss: 0.1584 - mae: 0.4941 - val_loss: 1.2280 - val_mae: 1.7280 - 1s/epoch - 83ms/step
# Epoch 70/400
# 13/13 - 1s - loss: 0.1573 - mae: 0.4948 - val_loss: 1.2279 - val_mae: 1.7279 - 966ms/epoch - 74ms/step
# Epoch 71/400
# 13/13 - 1s - loss: 0.1581 - mae: 0.4953 - val_loss: 1.2273 - val_mae: 1.7273 - 1s/epoch - 86ms/step
# Epoch 72/400
# 13/13 - 1s - loss: 0.1556 - mae: 0.4905 - val_loss: 1.2258 - val_mae: 1.7258 - 910ms/epoch - 70ms/step
# Epoch 73/400
# 13/13 - 1s - loss: 0.1529 - mae: 0.4868 - val_loss: 1.2252 - val_mae: 1.7252 - 1s/epoch - 86ms/step
# Epoch 74/400
# 13/13 - 1s - loss: 0.1561 - mae: 0.4908 - val_loss: 1.2245 - val_mae: 1.7245 - 890ms/epoch - 68ms/step
# Epoch 75/400
# 13/13 - 1s - loss: 0.1539 - mae: 0.4868 - val_loss: 1.2235 - val_mae: 1.7235 - 900ms/epoch - 69ms/step
# Epoch 76/400
# 13/13 - 1s - loss: 0.1547 - mae: 0.4877 - val_loss: 1.2229 - val_mae: 1.7229 - 1s/epoch - 90ms/step
# Epoch 77/400
# 13/13 - 1s - loss: 0.1501 - mae: 0.4845 - val_loss: 1.2216 - val_mae: 1.7216 - 961ms/epoch - 74ms/step
# Epoch 78/400
# 13/13 - 1s - loss: 0.1508 - mae: 0.4804 - val_loss: 1.2203 - val_mae: 1.7203 - 964ms/epoch - 74ms/step
# Epoch 79/400
# 13/13 - 1s - loss: 0.1498 - mae: 0.4790 - val_loss: 1.2195 - val_mae: 1.7195 - 892ms/epoch - 69ms/step
# Epoch 80/400
# 13/13 - 1s - loss: 0.1476 - mae: 0.4767 - val_loss: 1.2184 - val_mae: 1.7184 - 1s/epoch - 98ms/step
# Epoch 81/400
# 13/13 - 1s - loss: 0.1513 - mae: 0.4812 - val_loss: 1.2176 - val_mae: 1.7176 - 1s/epoch - 85ms/step
# Epoch 82/400
# 13/13 - 1s - loss: 0.1485 - mae: 0.4781 - val_loss: 1.2173 - val_mae: 1.7173 - 889ms/epoch - 68ms/step
# Epoch 83/400
# 13/13 - 1s - loss: 0.1479 - mae: 0.4739 - val_loss: 1.2162 - val_mae: 1.7162 - 960ms/epoch - 74ms/step
# Epoch 84/400
# 13/13 - 1s - loss: 0.1506 - mae: 0.4812 - val_loss: 1.2152 - val_mae: 1.7152 - 903ms/epoch - 69ms/step
# Epoch 85/400
# 13/13 - 1s - loss: 0.1460 - mae: 0.4738 - val_loss: 1.2140 - val_mae: 1.7140 - 897ms/epoch - 69ms/step
# Epoch 86/400
# 13/13 - 1s - loss: 0.1493 - mae: 0.4775 - val_loss: 1.2132 - val_mae: 1.7132 - 1s/epoch - 79ms/step
# Epoch 87/400
# 13/13 - 1s - loss: 0.1459 - mae: 0.4752 - val_loss: 1.2116 - val_mae: 1.7116 - 919ms/epoch - 71ms/step
# Epoch 88/400
# 13/13 - 1s - loss: 0.1471 - mae: 0.4734 - val_loss: 1.2105 - val_mae: 1.7105 - 1s/epoch - 84ms/step
# Epoch 89/400
# 13/13 - 1s - loss: 0.1418 - mae: 0.4634 - val_loss: 1.2099 - val_mae: 1.7099 - 981ms/epoch - 75ms/step
# Epoch 90/400
# 13/13 - 1s - loss: 0.1453 - mae: 0.4693 - val_loss: 1.2084 - val_mae: 1.7084 - 939ms/epoch - 72ms/step
# Epoch 91/400
# 13/13 - 1s - loss: 0.1461 - mae: 0.4732 - val_loss: 1.2074 - val_mae: 1.7074 - 1s/epoch - 83ms/step
# Epoch 92/400
# 13/13 - 1s - loss: 0.1453 - mae: 0.4715 - val_loss: 1.2056 - val_mae: 1.7056 - 1s/epoch - 87ms/step
# Epoch 93/400
# 13/13 - 1s - loss: 0.1405 - mae: 0.4627 - val_loss: 1.2045 - val_mae: 1.7045 - 1s/epoch - 79ms/step
# Epoch 94/400
# 13/13 - 1s - loss: 0.1391 - mae: 0.4602 - val_loss: 1.2034 - val_mae: 1.7034 - 1s/epoch - 87ms/step
# Epoch 95/400
# 13/13 - 1s - loss: 0.1394 - mae: 0.4594 - val_loss: 1.2018 - val_mae: 1.7018 - 1s/epoch - 84ms/step
# Epoch 96/400
# 13/13 - 1s - loss: 0.1406 - mae: 0.4622 - val_loss: 1.2007 - val_mae: 1.7007 - 955ms/epoch - 73ms/step
# Epoch 97/400
# 13/13 - 1s - loss: 0.1353 - mae: 0.4534 - val_loss: 1.2001 - val_mae: 1.7001 - 957ms/epoch - 74ms/step
# Epoch 98/400
# 13/13 - 1s - loss: 0.1399 - mae: 0.4619 - val_loss: 1.1986 - val_mae: 1.6986 - 930ms/epoch - 72ms/step
# Epoch 99/400
# 13/13 - 1s - loss: 0.1384 - mae: 0.4549 - val_loss: 1.1976 - val_mae: 1.6976 - 871ms/epoch - 67ms/step
# Epoch 100/400
# 13/13 - 1s - loss: 0.1385 - mae: 0.4576 - val_loss: 1.1963 - val_mae: 1.6963 - 954ms/epoch - 73ms/step
# Epoch 101/400
# 13/13 - 1s - loss: 0.1347 - mae: 0.4516 - val_loss: 1.1948 - val_mae: 1.6948 - 1s/epoch - 77ms/step
# Epoch 102/400
# 13/13 - 1s - loss: 0.1347 - mae: 0.4499 - val_loss: 1.1935 - val_mae: 1.6935 - 1s/epoch - 80ms/step
# Epoch 103/400
# 13/13 - 1s - loss: 0.1334 - mae: 0.4473 - val_loss: 1.1921 - val_mae: 1.6921 - 891ms/epoch - 69ms/step
# Epoch 104/400
# 13/13 - 1s - loss: 0.1328 - mae: 0.4464 - val_loss: 1.1904 - val_mae: 1.6904 - 945ms/epoch - 73ms/step
# Epoch 105/400
# 13/13 - 1s - loss: 0.1353 - mae: 0.4510 - val_loss: 1.1890 - val_mae: 1.6890 - 945ms/epoch - 73ms/step
# Epoch 106/400
# 13/13 - 1s - loss: 0.1311 - mae: 0.4451 - val_loss: 1.1878 - val_mae: 1.6878 - 1s/epoch - 94ms/step
# Epoch 107/400
# 13/13 - 1s - loss: 0.1324 - mae: 0.4444 - val_loss: 1.1865 - val_mae: 1.6865 - 1s/epoch - 79ms/step
# Epoch 108/400
# 13/13 - 1s - loss: 0.1342 - mae: 0.4483 - val_loss: 1.1852 - val_mae: 1.6852 - 864ms/epoch - 66ms/step
# Epoch 109/400
# 13/13 - 1s - loss: 0.1329 - mae: 0.4437 - val_loss: 1.1837 - val_mae: 1.6837 - 913ms/epoch - 70ms/step
# Epoch 110/400
# 13/13 - 1s - loss: 0.1283 - mae: 0.4376 - val_loss: 1.1818 - val_mae: 1.6818 - 1s/epoch - 80ms/step
# Epoch 111/400
# 13/13 - 1s - loss: 0.1322 - mae: 0.4453 - val_loss: 1.1803 - val_mae: 1.6803 - 1s/epoch - 77ms/step
# Epoch 112/400
# 13/13 - 1s - loss: 0.1314 - mae: 0.4449 - val_loss: 1.1789 - val_mae: 1.6789 - 896ms/epoch - 69ms/step
# Epoch 113/400
# 13/13 - 1s - loss: 0.1286 - mae: 0.4369 - val_loss: 1.1769 - val_mae: 1.6769 - 1s/epoch - 83ms/step
# Epoch 114/400
# 13/13 - 1s - loss: 0.1280 - mae: 0.4390 - val_loss: 1.1757 - val_mae: 1.6757 - 938ms/epoch - 72ms/step
# Epoch 115/400
# 13/13 - 1s - loss: 0.1253 - mae: 0.4362 - val_loss: 1.1739 - val_mae: 1.6739 - 921ms/epoch - 71ms/step
# Epoch 116/400
# 13/13 - 1s - loss: 0.1289 - mae: 0.4379 - val_loss: 1.1719 - val_mae: 1.6719 - 928ms/epoch - 71ms/step
# Epoch 117/400
# 13/13 - 1s - loss: 0.1242 - mae: 0.4324 - val_loss: 1.1707 - val_mae: 1.6707 - 941ms/epoch - 72ms/step
# Epoch 118/400
# 13/13 - 1s - loss: 0.1253 - mae: 0.4361 - val_loss: 1.1687 - val_mae: 1.6687 - 925ms/epoch - 71ms/step
# Epoch 119/400
# 13/13 - 1s - loss: 0.1202 - mae: 0.4228 - val_loss: 1.1668 - val_mae: 1.6668 - 869ms/epoch - 67ms/step
# Epoch 120/400
# 13/13 - 1s - loss: 0.1248 - mae: 0.4309 - val_loss: 1.1650 - val_mae: 1.6650 - 1s/epoch - 91ms/step
# Epoch 121/400
# 13/13 - 1s - loss: 0.1242 - mae: 0.4296 - val_loss: 1.1633 - val_mae: 1.6633 - 1s/epoch - 88ms/step
# Epoch 122/400
# 13/13 - 1s - loss: 0.1274 - mae: 0.4348 - val_loss: 1.1615 - val_mae: 1.6615 - 1s/epoch - 88ms/step
# Epoch 123/400
# 13/13 - 1s - loss: 0.1196 - mae: 0.4182 - val_loss: 1.1593 - val_mae: 1.6593 - 1s/epoch - 83ms/step
# Epoch 124/400
# 13/13 - 1s - loss: 0.1223 - mae: 0.4260 - val_loss: 1.1572 - val_mae: 1.6572 - 1s/epoch - 81ms/step
# Epoch 125/400
# 13/13 - 1s - loss: 0.1214 - mae: 0.4241 - val_loss: 1.1553 - val_mae: 1.6553 - 1s/epoch - 80ms/step
# Epoch 126/400
# 13/13 - 1s - loss: 0.1259 - mae: 0.4294 - val_loss: 1.1535 - val_mae: 1.6535 - 1s/epoch - 85ms/step
# Epoch 127/400
# 13/13 - 1s - loss: 0.1230 - mae: 0.4246 - val_loss: 1.1518 - val_mae: 1.6518 - 1s/epoch - 80ms/step
# Epoch 128/400
# 13/13 - 1s - loss: 0.1220 - mae: 0.4219 - val_loss: 1.1498 - val_mae: 1.6498 - 1s/epoch - 81ms/step
# Epoch 129/400
# 13/13 - 1s - loss: 0.1176 - mae: 0.4162 - val_loss: 1.1478 - val_mae: 1.6478 - 929ms/epoch - 71ms/step
# Epoch 130/400
# 13/13 - 1s - loss: 0.1181 - mae: 0.4162 - val_loss: 1.1456 - val_mae: 1.6456 - 934ms/epoch - 72ms/step
# Epoch 131/400
# 13/13 - 1s - loss: 0.1193 - mae: 0.4203 - val_loss: 1.1433 - val_mae: 1.6433 - 910ms/epoch - 70ms/step
# Epoch 132/400
# 13/13 - 1s - loss: 0.1147 - mae: 0.4098 - val_loss: 1.1410 - val_mae: 1.6410 - 846ms/epoch - 65ms/step
# Epoch 133/400
# 13/13 - 1s - loss: 0.1173 - mae: 0.4127 - val_loss: 1.1391 - val_mae: 1.6391 - 1s/epoch - 78ms/step
# Epoch 134/400
# 13/13 - 1s - loss: 0.1115 - mae: 0.4042 - val_loss: 1.1367 - val_mae: 1.6367 - 954ms/epoch - 73ms/step
# Epoch 135/400
# 13/13 - 1s - loss: 0.1125 - mae: 0.4042 - val_loss: 1.1336 - val_mae: 1.6336 - 949ms/epoch - 73ms/step
# Epoch 136/400
# 13/13 - 1s - loss: 0.1109 - mae: 0.4026 - val_loss: 1.1315 - val_mae: 1.6315 - 987ms/epoch - 76ms/step
# Epoch 137/400
# 13/13 - 1s - loss: 0.1133 - mae: 0.4065 - val_loss: 1.1289 - val_mae: 1.6289 - 1s/epoch - 77ms/step
# Epoch 138/400
# 13/13 - 1s - loss: 0.1091 - mae: 0.3999 - val_loss: 1.1263 - val_mae: 1.6263 - 1s/epoch - 82ms/step
# Epoch 139/400
# 13/13 - 1s - loss: 0.1090 - mae: 0.4007 - val_loss: 1.1239 - val_mae: 1.6239 - 890ms/epoch - 68ms/step
# Epoch 140/400
# 13/13 - 1s - loss: 0.1111 - mae: 0.4037 - val_loss: 1.1219 - val_mae: 1.6219 - 893ms/epoch - 69ms/step
# Epoch 141/400
# 13/13 - 1s - loss: 0.1090 - mae: 0.4022 - val_loss: 1.1196 - val_mae: 1.6196 - 893ms/epoch - 69ms/step
# Epoch 142/400
# 13/13 - 1s - loss: 0.1117 - mae: 0.4019 - val_loss: 1.1170 - val_mae: 1.6170 - 940ms/epoch - 72ms/step
# Epoch 143/400
# 13/13 - 1s - loss: 0.1070 - mae: 0.3932 - val_loss: 1.1148 - val_mae: 1.6148 - 1s/epoch - 85ms/step
# Epoch 144/400
# 13/13 - 1s - loss: 0.1096 - mae: 0.3997 - val_loss: 1.1123 - val_mae: 1.6123 - 959ms/epoch - 74ms/step
# Epoch 145/400
# 13/13 - 1s - loss: 0.1097 - mae: 0.3979 - val_loss: 1.1098 - val_mae: 1.6098 - 924ms/epoch - 71ms/step
# Epoch 146/400
# 13/13 - 1s - loss: 0.1066 - mae: 0.3951 - val_loss: 1.1073 - val_mae: 1.6073 - 871ms/epoch - 67ms/step
# Epoch 147/400
# 13/13 - 1s - loss: 0.1064 - mae: 0.3930 - val_loss: 1.1048 - val_mae: 1.6048 - 924ms/epoch - 71ms/step
# Epoch 148/400
# 13/13 - 1s - loss: 0.1071 - mae: 0.3903 - val_loss: 1.1022 - val_mae: 1.6022 - 917ms/epoch - 71ms/step
# Epoch 149/400
# 13/13 - 1s - loss: 0.0995 - mae: 0.3797 - val_loss: 1.0997 - val_mae: 1.5997 - 1s/epoch - 91ms/step
# Epoch 150/400
# 13/13 - 1s - loss: 0.1036 - mae: 0.3849 - val_loss: 1.0976 - val_mae: 1.5976 - 1s/epoch - 88ms/step
# Epoch 151/400
# 13/13 - 1s - loss: 0.1000 - mae: 0.3776 - val_loss: 1.0954 - val_mae: 1.5954 - 1s/epoch - 90ms/step
# Epoch 152/400
# 13/13 - 1s - loss: 0.1034 - mae: 0.3869 - val_loss: 1.0927 - val_mae: 1.5927 - 894ms/epoch - 69ms/step
# Epoch 153/400
# 13/13 - 1s - loss: 0.1008 - mae: 0.3816 - val_loss: 1.0901 - val_mae: 1.5901 - 1s/epoch - 77ms/step
# Epoch 154/400
# 13/13 - 1s - loss: 0.1024 - mae: 0.3847 - val_loss: 1.0873 - val_mae: 1.5873 - 967ms/epoch - 74ms/step
# Epoch 155/400
# 13/13 - 1s - loss: 0.0988 - mae: 0.3738 - val_loss: 1.0844 - val_mae: 1.5844 - 1s/epoch - 86ms/step
# Epoch 156/400
# 13/13 - 1s - loss: 0.0987 - mae: 0.3748 - val_loss: 1.0813 - val_mae: 1.5813 - 932ms/epoch - 72ms/step
# Epoch 157/400
# 13/13 - 1s - loss: 0.0993 - mae: 0.3772 - val_loss: 1.0785 - val_mae: 1.5785 - 916ms/epoch - 70ms/step
# Epoch 158/400
# 13/13 - 1s - loss: 0.0964 - mae: 0.3740 - val_loss: 1.0759 - val_mae: 1.5759 - 880ms/epoch - 68ms/step
# Epoch 159/400
# 13/13 - 1s - loss: 0.1006 - mae: 0.3815 - val_loss: 1.0726 - val_mae: 1.5726 - 945ms/epoch - 73ms/step
# Epoch 160/400
# 13/13 - 1s - loss: 0.0966 - mae: 0.3696 - val_loss: 1.0700 - val_mae: 1.5700 - 936ms/epoch - 72ms/step
# Epoch 161/400
# 13/13 - 1s - loss: 0.0978 - mae: 0.3736 - val_loss: 1.0670 - val_mae: 1.5670 - 1s/epoch - 97ms/step
# Epoch 162/400
# 13/13 - 1s - loss: 0.0964 - mae: 0.3722 - val_loss: 1.0637 - val_mae: 1.5637 - 1s/epoch - 84ms/step
# Epoch 163/400
# 13/13 - 1s - loss: 0.0925 - mae: 0.3577 - val_loss: 1.0606 - val_mae: 1.5606 - 993ms/epoch - 76ms/step
# Epoch 164/400
# 13/13 - 1s - loss: 0.0895 - mae: 0.3563 - val_loss: 1.0577 - val_mae: 1.5577 - 1s/epoch - 87ms/step
# Epoch 165/400
# 13/13 - 1s - loss: 0.0992 - mae: 0.3730 - val_loss: 1.0546 - val_mae: 1.5546 - 1s/epoch - 91ms/step
# Epoch 166/400
# 13/13 - 1s - loss: 0.0957 - mae: 0.3653 - val_loss: 1.0522 - val_mae: 1.5522 - 1s/epoch - 99ms/step
# Epoch 167/400
# 13/13 - 1s - loss: 0.0938 - mae: 0.3628 - val_loss: 1.0498 - val_mae: 1.5498 - 1s/epoch - 92ms/step
# Epoch 168/400
# 13/13 - 1s - loss: 0.0984 - mae: 0.3713 - val_loss: 1.0465 - val_mae: 1.5465 - 1s/epoch - 84ms/step
# Epoch 169/400
# 13/13 - 1s - loss: 0.0935 - mae: 0.3663 - val_loss: 1.0435 - val_mae: 1.5435 - 909ms/epoch - 70ms/step
# Epoch 170/400
# 13/13 - 1s - loss: 0.0927 - mae: 0.3520 - val_loss: 1.0410 - val_mae: 1.5410 - 903ms/epoch - 69ms/step
# Epoch 171/400
# 13/13 - 1s - loss: 0.0921 - mae: 0.3586 - val_loss: 1.0384 - val_mae: 1.5384 - 999ms/epoch - 77ms/step
# Epoch 172/400
# 13/13 - 1s - loss: 0.0910 - mae: 0.3551 - val_loss: 1.0351 - val_mae: 1.5351 - 1s/epoch - 84ms/step
# Epoch 173/400
# 13/13 - 1s - loss: 0.0876 - mae: 0.3507 - val_loss: 1.0322 - val_mae: 1.5322 - 899ms/epoch - 69ms/step
# Epoch 174/400
# 13/13 - 1s - loss: 0.0867 - mae: 0.3415 - val_loss: 1.0297 - val_mae: 1.5297 - 910ms/epoch - 70ms/step
# Epoch 175/400
# 13/13 - 1s - loss: 0.0862 - mae: 0.3468 - val_loss: 1.0272 - val_mae: 1.5272 - 929ms/epoch - 71ms/step
# Epoch 176/400
# 13/13 - 1s - loss: 0.0869 - mae: 0.3440 - val_loss: 1.0240 - val_mae: 1.5240 - 936ms/epoch - 72ms/step
# Epoch 177/400
# 13/13 - 1s - loss: 0.0865 - mae: 0.3416 - val_loss: 1.0212 - val_mae: 1.5212 - 995ms/epoch - 77ms/step
# Epoch 178/400
# 13/13 - 1s - loss: 0.0846 - mae: 0.3389 - val_loss: 1.0182 - val_mae: 1.5182 - 919ms/epoch - 71ms/step
# Epoch 179/400
# 13/13 - 1s - loss: 0.0875 - mae: 0.3420 - val_loss: 1.0154 - val_mae: 1.5154 - 897ms/epoch - 69ms/step
# Epoch 180/400
# 13/13 - 1s - loss: 0.0895 - mae: 0.3505 - val_loss: 1.0119 - val_mae: 1.5119 - 897ms/epoch - 69ms/step
# Epoch 181/400
# 13/13 - 1s - loss: 0.0836 - mae: 0.3337 - val_loss: 1.0087 - val_mae: 1.5087 - 1s/epoch - 81ms/step
# Epoch 182/400
# 13/13 - 1s - loss: 0.0831 - mae: 0.3313 - val_loss: 1.0053 - val_mae: 1.5053 - 893ms/epoch - 69ms/step
# Epoch 183/400
# 13/13 - 1s - loss: 0.0770 - mae: 0.3224 - val_loss: 1.0022 - val_mae: 1.5022 - 859ms/epoch - 66ms/step
# Epoch 184/400
# 13/13 - 1s - loss: 0.0865 - mae: 0.3452 - val_loss: 0.9994 - val_mae: 1.4994 - 1s/epoch - 80ms/step
# Epoch 185/400
# 13/13 - 1s - loss: 0.0822 - mae: 0.3325 - val_loss: 0.9959 - val_mae: 1.4959 - 1s/epoch - 87ms/step
# Epoch 186/400
# 13/13 - 1s - loss: 0.0831 - mae: 0.3384 - val_loss: 0.9924 - val_mae: 1.4924 - 963ms/epoch - 74ms/step
# Epoch 187/400
# 13/13 - 1s - loss: 0.0811 - mae: 0.3299 - val_loss: 0.9893 - val_mae: 1.4893 - 944ms/epoch - 73ms/step
# Epoch 188/400
# 13/13 - 1s - loss: 0.0859 - mae: 0.3420 - val_loss: 0.9859 - val_mae: 1.4859 - 955ms/epoch - 73ms/step
# Epoch 189/400
# 13/13 - 1s - loss: 0.0832 - mae: 0.3327 - val_loss: 0.9832 - val_mae: 1.4832 - 1s/epoch - 80ms/step
# Epoch 190/400
# 13/13 - 1s - loss: 0.0772 - mae: 0.3194 - val_loss: 0.9801 - val_mae: 1.4801 - 1s/epoch - 79ms/step
# Epoch 191/400
# 13/13 - 1s - loss: 0.0762 - mae: 0.3187 - val_loss: 0.9760 - val_mae: 1.4760 - 869ms/epoch - 67ms/step
# Epoch 192/400
# 13/13 - 1s - loss: 0.0783 - mae: 0.3234 - val_loss: 0.9724 - val_mae: 1.4724 - 928ms/epoch - 71ms/step
# Epoch 193/400
# 13/13 - 1s - loss: 0.0766 - mae: 0.3176 - val_loss: 0.9685 - val_mae: 1.4685 - 975ms/epoch - 75ms/step
# Epoch 194/400
# 13/13 - 1s - loss: 0.0732 - mae: 0.3055 - val_loss: 0.9648 - val_mae: 1.4648 - 1s/epoch - 94ms/step
# Epoch 195/400
# 13/13 - 1s - loss: 0.0745 - mae: 0.3170 - val_loss: 0.9615 - val_mae: 1.4615 - 997ms/epoch - 77ms/step
# Epoch 196/400
# 13/13 - 1s - loss: 0.0746 - mae: 0.3166 - val_loss: 0.9585 - val_mae: 1.4585 - 1s/epoch - 80ms/step
# Epoch 197/400
# 13/13 - 1s - loss: 0.0703 - mae: 0.3054 - val_loss: 0.9546 - val_mae: 1.4546 - 907ms/epoch - 70ms/step
# Epoch 198/400
# 13/13 - 1s - loss: 0.0753 - mae: 0.3092 - val_loss: 0.9511 - val_mae: 1.4511 - 973ms/epoch - 75ms/step
# Epoch 199/400
# 13/13 - 1s - loss: 0.0688 - mae: 0.2993 - val_loss: 0.9478 - val_mae: 1.4478 - 942ms/epoch - 72ms/step
# Epoch 200/400
# 13/13 - 1s - loss: 0.0701 - mae: 0.3005 - val_loss: 0.9438 - val_mae: 1.4438 - 975ms/epoch - 75ms/step
# Epoch 201/400
# 13/13 - 1s - loss: 0.0793 - mae: 0.3207 - val_loss: 0.9402 - val_mae: 1.4402 - 882ms/epoch - 68ms/step
# Epoch 202/400
# 13/13 - 1s - loss: 0.0672 - mae: 0.2903 - val_loss: 0.9363 - val_mae: 1.4363 - 948ms/epoch - 73ms/step
# Epoch 203/400
# 13/13 - 1s - loss: 0.0652 - mae: 0.2895 - val_loss: 0.9326 - val_mae: 1.4326 - 961ms/epoch - 74ms/step
# Epoch 204/400
# 13/13 - 1s - loss: 0.0711 - mae: 0.2983 - val_loss: 0.9287 - val_mae: 1.4287 - 1s/epoch - 77ms/step
# Epoch 205/400
# 13/13 - 1s - loss: 0.0678 - mae: 0.2952 - val_loss: 0.9250 - val_mae: 1.4250 - 1s/epoch - 85ms/step
# Epoch 206/400
# 13/13 - 1s - loss: 0.0731 - mae: 0.3086 - val_loss: 0.9208 - val_mae: 1.4208 - 1s/epoch - 83ms/step
# Epoch 207/400
# 13/13 - 1s - loss: 0.0680 - mae: 0.2952 - val_loss: 0.9173 - val_mae: 1.4172 - 1s/epoch - 82ms/step
# Epoch 208/400
# 13/13 - 1s - loss: 0.0685 - mae: 0.2943 - val_loss: 0.9146 - val_mae: 1.4146 - 1s/epoch - 79ms/step
# Epoch 209/400
# 13/13 - 1s - loss: 0.0630 - mae: 0.2821 - val_loss: 0.9112 - val_mae: 1.4112 - 919ms/epoch - 71ms/step
# Epoch 210/400
# 13/13 - 1s - loss: 0.0657 - mae: 0.2915 - val_loss: 0.9073 - val_mae: 1.4073 - 941ms/epoch - 72ms/step
# Epoch 211/400
# 13/13 - 1s - loss: 0.0693 - mae: 0.2969 - val_loss: 0.9033 - val_mae: 1.4033 - 943ms/epoch - 73ms/step
# Epoch 212/400
# 13/13 - 1s - loss: 0.0627 - mae: 0.2781 - val_loss: 0.8999 - val_mae: 1.3999 - 1s/epoch - 78ms/step
# Epoch 213/400
# 13/13 - 1s - loss: 0.0646 - mae: 0.2845 - val_loss: 0.8960 - val_mae: 1.3959 - 948ms/epoch - 73ms/step
# Epoch 214/400
# 13/13 - 1s - loss: 0.0605 - mae: 0.2723 - val_loss: 0.8921 - val_mae: 1.3920 - 887ms/epoch - 68ms/step
# Epoch 215/400
# 13/13 - 1s - loss: 0.0614 - mae: 0.2763 - val_loss: 0.8885 - val_mae: 1.3884 - 893ms/epoch - 69ms/step
# Epoch 216/400
# 13/13 - 1s - loss: 0.0597 - mae: 0.2746 - val_loss: 0.8843 - val_mae: 1.3842 - 972ms/epoch - 75ms/step
# Epoch 217/400
# 13/13 - 1s - loss: 0.0626 - mae: 0.2776 - val_loss: 0.8807 - val_mae: 1.3806 - 905ms/epoch - 70ms/step
# Epoch 218/400
# 13/13 - 1s - loss: 0.0593 - mae: 0.2727 - val_loss: 0.8767 - val_mae: 1.3766 - 938ms/epoch - 72ms/step
# Epoch 219/400
# 13/13 - 1s - loss: 0.0572 - mae: 0.2588 - val_loss: 0.8730 - val_mae: 1.3730 - 872ms/epoch - 67ms/step
# Epoch 220/400
# 13/13 - 1s - loss: 0.0582 - mae: 0.2655 - val_loss: 0.8686 - val_mae: 1.3685 - 933ms/epoch - 72ms/step
# Epoch 221/400
# 13/13 - 1s - loss: 0.0614 - mae: 0.2687 - val_loss: 0.8644 - val_mae: 1.3643 - 937ms/epoch - 72ms/step
# Epoch 222/400
# 13/13 - 1s - loss: 0.0576 - mae: 0.2657 - val_loss: 0.8603 - val_mae: 1.3601 - 912ms/epoch - 70ms/step
# Epoch 223/400
# 13/13 - 1s - loss: 0.0563 - mae: 0.2592 - val_loss: 0.8564 - val_mae: 1.3562 - 953ms/epoch - 73ms/step
# Epoch 224/400
# 13/13 - 1s - loss: 0.0609 - mae: 0.2701 - val_loss: 0.8529 - val_mae: 1.3527 - 1s/epoch - 84ms/step
# Epoch 225/400
# 13/13 - 1s - loss: 0.0588 - mae: 0.2641 - val_loss: 0.8489 - val_mae: 1.3487 - 944ms/epoch - 73ms/step
# Epoch 226/400
# 13/13 - 1s - loss: 0.0592 - mae: 0.2695 - val_loss: 0.8446 - val_mae: 1.3443 - 853ms/epoch - 66ms/step
# Epoch 227/400
# 13/13 - 1s - loss: 0.0565 - mae: 0.2563 - val_loss: 0.8406 - val_mae: 1.3404 - 1s/epoch - 83ms/step
# Epoch 228/400
# 13/13 - 1s - loss: 0.0527 - mae: 0.2491 - val_loss: 0.8366 - val_mae: 1.3363 - 1s/epoch - 77ms/step
# Epoch 229/400
# 13/13 - 1s - loss: 0.0571 - mae: 0.2611 - val_loss: 0.8332 - val_mae: 1.3329 - 878ms/epoch - 68ms/step
# Epoch 230/400
# 13/13 - 1s - loss: 0.0583 - mae: 0.2605 - val_loss: 0.8291 - val_mae: 1.3288 - 956ms/epoch - 74ms/step
# Epoch 231/400
# 13/13 - 1s - loss: 0.0543 - mae: 0.2489 - val_loss: 0.8255 - val_mae: 1.3251 - 995ms/epoch - 77ms/step
# Epoch 232/400
# 13/13 - 1s - loss: 0.0582 - mae: 0.2613 - val_loss: 0.8219 - val_mae: 1.3215 - 940ms/epoch - 72ms/step
# Epoch 233/400
# 13/13 - 1s - loss: 0.0539 - mae: 0.2501 - val_loss: 0.8179 - val_mae: 1.3175 - 1s/epoch - 85ms/step
# Epoch 234/400
# 13/13 - 1s - loss: 0.0525 - mae: 0.2482 - val_loss: 0.8142 - val_mae: 1.3138 - 969ms/epoch - 75ms/step
# Epoch 235/400
# 13/13 - 1s - loss: 0.0494 - mae: 0.2339 - val_loss: 0.8101 - val_mae: 1.3097 - 1s/epoch - 81ms/step
# Epoch 236/400
# 13/13 - 1s - loss: 0.0437 - mae: 0.2266 - val_loss: 0.8062 - val_mae: 1.3057 - 956ms/epoch - 74ms/step
# Epoch 237/400
# 13/13 - 1s - loss: 0.0514 - mae: 0.2327 - val_loss: 0.8018 - val_mae: 1.3013 - 948ms/epoch - 73ms/step
# Epoch 238/400
# 13/13 - 1s - loss: 0.0510 - mae: 0.2460 - val_loss: 0.7980 - val_mae: 1.2974 - 995ms/epoch - 77ms/step
# Epoch 239/400
# 13/13 - 1s - loss: 0.0493 - mae: 0.2413 - val_loss: 0.7941 - val_mae: 1.2934 - 1s/epoch - 82ms/step
# Epoch 240/400
# 13/13 - 1s - loss: 0.0478 - mae: 0.2309 - val_loss: 0.7902 - val_mae: 1.2895 - 937ms/epoch - 72ms/step
# Epoch 241/400
# 13/13 - 1s - loss: 0.0566 - mae: 0.2511 - val_loss: 0.7865 - val_mae: 1.2858 - 921ms/epoch - 71ms/step
# Epoch 242/400
# 13/13 - 1s - loss: 0.0533 - mae: 0.2465 - val_loss: 0.7827 - val_mae: 1.2820 - 992ms/epoch - 76ms/step
# Epoch 243/400
# 13/13 - 1s - loss: 0.0451 - mae: 0.2187 - val_loss: 0.7784 - val_mae: 1.2776 - 1s/epoch - 79ms/step
# Epoch 244/400
# 13/13 - 1s - loss: 0.0450 - mae: 0.2238 - val_loss: 0.7745 - val_mae: 1.2736 - 955ms/epoch - 73ms/step
# Epoch 245/400
# 13/13 - 1s - loss: 0.0474 - mae: 0.2353 - val_loss: 0.7706 - val_mae: 1.2697 - 916ms/epoch - 70ms/step
# Epoch 246/400
# 13/13 - 1s - loss: 0.0467 - mae: 0.2259 - val_loss: 0.7669 - val_mae: 1.2660 - 953ms/epoch - 73ms/step
# Epoch 247/400
# 13/13 - 1s - loss: 0.0479 - mae: 0.2313 - val_loss: 0.7626 - val_mae: 1.2616 - 1s/epoch - 79ms/step
# Epoch 248/400
# 13/13 - 1s - loss: 0.0485 - mae: 0.2306 - val_loss: 0.7586 - val_mae: 1.2575 - 1s/epoch - 83ms/step
# Epoch 249/400
# 13/13 - 1s - loss: 0.0444 - mae: 0.2262 - val_loss: 0.7545 - val_mae: 1.2534 - 939ms/epoch - 72ms/step
# Epoch 250/400
# 13/13 - 1s - loss: 0.0489 - mae: 0.2278 - val_loss: 0.7506 - val_mae: 1.2494 - 933ms/epoch - 72ms/step
# Epoch 251/400
# 13/13 - 1s - loss: 0.0439 - mae: 0.2158 - val_loss: 0.7474 - val_mae: 1.2462 - 920ms/epoch - 71ms/step
# Epoch 252/400
# 13/13 - 1s - loss: 0.0430 - mae: 0.2142 - val_loss: 0.7434 - val_mae: 1.2421 - 880ms/epoch - 68ms/step
# Epoch 253/400
# 13/13 - 1s - loss: 0.0419 - mae: 0.2163 - val_loss: 0.7398 - val_mae: 1.2384 - 1s/epoch - 80ms/step
# Epoch 254/400
# 13/13 - 1s - loss: 0.0456 - mae: 0.2155 - val_loss: 0.7360 - val_mae: 1.2345 - 1s/epoch - 83ms/step
# Epoch 255/400
# 13/13 - 1s - loss: 0.0434 - mae: 0.2187 - val_loss: 0.7317 - val_mae: 1.2302 - 1s/epoch - 78ms/step
# Epoch 256/400
# 13/13 - 1s - loss: 0.0415 - mae: 0.2101 - val_loss: 0.7272 - val_mae: 1.2255 - 958ms/epoch - 74ms/step
# Epoch 257/400
# 13/13 - 1s - loss: 0.0439 - mae: 0.2118 - val_loss: 0.7233 - val_mae: 1.2216 - 1s/epoch - 78ms/step
# Epoch 258/400
# 13/13 - 1s - loss: 0.0408 - mae: 0.2080 - val_loss: 0.7188 - val_mae: 1.2170 - 990ms/epoch - 76ms/step
# Epoch 259/400
# 13/13 - 1s - loss: 0.0377 - mae: 0.2040 - val_loss: 0.7144 - val_mae: 1.2125 - 888ms/epoch - 68ms/step
# Epoch 260/400
# 13/13 - 1s - loss: 0.0428 - mae: 0.2144 - val_loss: 0.7102 - val_mae: 1.2082 - 1s/epoch - 77ms/step
# Epoch 261/400
# 13/13 - 1s - loss: 0.0454 - mae: 0.2193 - val_loss: 0.7068 - val_mae: 1.2047 - 898ms/epoch - 69ms/step
# Epoch 262/400
# 13/13 - 1s - loss: 0.0391 - mae: 0.2002 - val_loss: 0.7030 - val_mae: 1.2008 - 1s/epoch - 84ms/step
# Epoch 263/400
# 13/13 - 1s - loss: 0.0386 - mae: 0.1962 - val_loss: 0.6989 - val_mae: 1.1966 - 993ms/epoch - 76ms/step
# Epoch 264/400
# 13/13 - 1s - loss: 0.0405 - mae: 0.2042 - val_loss: 0.6950 - val_mae: 1.1926 - 963ms/epoch - 74ms/step
# Epoch 265/400
# 13/13 - 1s - loss: 0.0387 - mae: 0.2009 - val_loss: 0.6913 - val_mae: 1.1888 - 956ms/epoch - 74ms/step
# Epoch 266/400
# 13/13 - 1s - loss: 0.0402 - mae: 0.2052 - val_loss: 0.6878 - val_mae: 1.1851 - 926ms/epoch - 71ms/step
# Epoch 267/400
# 13/13 - 1s - loss: 0.0394 - mae: 0.1989 - val_loss: 0.6837 - val_mae: 1.1810 - 1s/epoch - 82ms/step
# Epoch 268/400
# 13/13 - 1s - loss: 0.0421 - mae: 0.2074 - val_loss: 0.6795 - val_mae: 1.1767 - 1s/epoch - 88ms/step
# Epoch 269/400
# 13/13 - 1s - loss: 0.0419 - mae: 0.2075 - val_loss: 0.6761 - val_mae: 1.1731 - 878ms/epoch - 68ms/step
# Epoch 270/400
# 13/13 - 1s - loss: 0.0372 - mae: 0.1982 - val_loss: 0.6720 - val_mae: 1.1689 - 912ms/epoch - 70ms/step
# Epoch 271/400
# 13/13 - 1s - loss: 0.0429 - mae: 0.2029 - val_loss: 0.6683 - val_mae: 1.1651 - 1s/epoch - 95ms/step
# Epoch 272/400
# 13/13 - 1s - loss: 0.0335 - mae: 0.1849 - val_loss: 0.6646 - val_mae: 1.1612 - 973ms/epoch - 75ms/step
# Epoch 273/400
# 13/13 - 1s - loss: 0.0401 - mae: 0.1963 - val_loss: 0.6608 - val_mae: 1.1573 - 953ms/epoch - 73ms/step
# Epoch 274/400
# 13/13 - 1s - loss: 0.0406 - mae: 0.2106 - val_loss: 0.6569 - val_mae: 1.1534 - 1s/epoch - 80ms/step
# Epoch 275/400
# 13/13 - 1s - loss: 0.0380 - mae: 0.1970 - val_loss: 0.6533 - val_mae: 1.1496 - 943ms/epoch - 73ms/step
# Epoch 276/400
# 13/13 - 1s - loss: 0.0345 - mae: 0.1849 - val_loss: 0.6495 - val_mae: 1.1457 - 1s/epoch - 79ms/step
# Epoch 277/400
# 13/13 - 1s - loss: 0.0337 - mae: 0.1797 - val_loss: 0.6455 - val_mae: 1.1415 - 1s/epoch - 88ms/step
# Epoch 278/400
# 13/13 - 1s - loss: 0.0345 - mae: 0.1893 - val_loss: 0.6416 - val_mae: 1.1374 - 1s/epoch - 88ms/step
# Epoch 279/400
# 13/13 - 1s - loss: 0.0326 - mae: 0.1737 - val_loss: 0.6376 - val_mae: 1.1333 - 972ms/epoch - 75ms/step
# Epoch 280/400
# 13/13 - 1s - loss: 0.0365 - mae: 0.1945 - val_loss: 0.6337 - val_mae: 1.1293 - 1s/epoch - 87ms/step
# Epoch 281/400
# 13/13 - 1s - loss: 0.0372 - mae: 0.1888 - val_loss: 0.6302 - val_mae: 1.1255 - 946ms/epoch - 73ms/step
# Epoch 282/400
# 13/13 - 1s - loss: 0.0359 - mae: 0.1847 - val_loss: 0.6263 - val_mae: 1.1216 - 987ms/epoch - 76ms/step
# Epoch 283/400
# 13/13 - 1s - loss: 0.0323 - mae: 0.1807 - val_loss: 0.6221 - val_mae: 1.1171 - 906ms/epoch - 70ms/step
# Epoch 284/400
# 13/13 - 1s - loss: 0.0301 - mae: 0.1687 - val_loss: 0.6182 - val_mae: 1.1131 - 1s/epoch - 78ms/step
# Epoch 285/400
# 13/13 - 1s - loss: 0.0350 - mae: 0.1871 - val_loss: 0.6142 - val_mae: 1.1089 - 995ms/epoch - 77ms/step
# Epoch 286/400
# 13/13 - 1s - loss: 0.0398 - mae: 0.1974 - val_loss: 0.6107 - val_mae: 1.1052 - 929ms/epoch - 71ms/step
# Epoch 287/400
# 13/13 - 1s - loss: 0.0388 - mae: 0.1945 - val_loss: 0.6070 - val_mae: 1.1014 - 880ms/epoch - 68ms/step
# Epoch 288/400
# 13/13 - 1s - loss: 0.0324 - mae: 0.1724 - val_loss: 0.6033 - val_mae: 1.0975 - 1s/epoch - 80ms/step
# Epoch 289/400
# 13/13 - 1s - loss: 0.0276 - mae: 0.1621 - val_loss: 0.5997 - val_mae: 1.0937 - 924ms/epoch - 71ms/step
# Epoch 290/400
# 13/13 - 1s - loss: 0.0323 - mae: 0.1800 - val_loss: 0.5964 - val_mae: 1.0902 - 937ms/epoch - 72ms/step
# Epoch 291/400
# 13/13 - 1s - loss: 0.0378 - mae: 0.1991 - val_loss: 0.5929 - val_mae: 1.0866 - 919ms/epoch - 71ms/step
# Epoch 292/400
# 13/13 - 1s - loss: 0.0286 - mae: 0.1681 - val_loss: 0.5890 - val_mae: 1.0825 - 1s/epoch - 79ms/step
# Epoch 293/400
# 13/13 - 1s - loss: 0.0324 - mae: 0.1867 - val_loss: 0.5859 - val_mae: 1.0792 - 1s/epoch - 89ms/step
# Epoch 294/400
# 13/13 - 1s - loss: 0.0314 - mae: 0.1751 - val_loss: 0.5827 - val_mae: 1.0758 - 1s/epoch - 81ms/step
# Epoch 295/400
# 13/13 - 1s - loss: 0.0296 - mae: 0.1667 - val_loss: 0.5790 - val_mae: 1.0719 - 953ms/epoch - 73ms/step
# Epoch 296/400
# 13/13 - 1s - loss: 0.0279 - mae: 0.1616 - val_loss: 0.5751 - val_mae: 1.0678 - 886ms/epoch - 68ms/step
# Epoch 297/400
# 13/13 - 1s - loss: 0.0279 - mae: 0.1639 - val_loss: 0.5715 - val_mae: 1.0640 - 1s/epoch - 77ms/step
# Epoch 298/400
# 13/13 - 1s - loss: 0.0275 - mae: 0.1578 - val_loss: 0.5675 - val_mae: 1.0597 - 918ms/epoch - 71ms/step
# Epoch 299/400
# 13/13 - 1s - loss: 0.0362 - mae: 0.1899 - val_loss: 0.5636 - val_mae: 1.0556 - 1s/epoch - 79ms/step
# Epoch 300/400
# 13/13 - 1s - loss: 0.0261 - mae: 0.1658 - val_loss: 0.5597 - val_mae: 1.0514 - 1s/epoch - 80ms/step
# Epoch 301/400
# 13/13 - 1s - loss: 0.0310 - mae: 0.1741 - val_loss: 0.5563 - val_mae: 1.0478 - 1s/epoch - 82ms/step
# Epoch 302/400
# 13/13 - 1s - loss: 0.0231 - mae: 0.1480 - val_loss: 0.5526 - val_mae: 1.0439 - 1s/epoch - 83ms/step
# Epoch 303/400
# 13/13 - 1s - loss: 0.0239 - mae: 0.1526 - val_loss: 0.5494 - val_mae: 1.0405 - 934ms/epoch - 72ms/step
# Epoch 304/400
# 13/13 - 1s - loss: 0.0288 - mae: 0.1659 - val_loss: 0.5464 - val_mae: 1.0373 - 918ms/epoch - 71ms/step
# Epoch 305/400
# 13/13 - 1s - loss: 0.0278 - mae: 0.1723 - val_loss: 0.5431 - val_mae: 1.0337 - 964ms/epoch - 74ms/step
# Epoch 306/400
# 13/13 - 1s - loss: 0.0350 - mae: 0.1866 - val_loss: 0.5402 - val_mae: 1.0306 - 967ms/epoch - 74ms/step
# Epoch 307/400
# 13/13 - 1s - loss: 0.0243 - mae: 0.1556 - val_loss: 0.5369 - val_mae: 1.0271 - 1s/epoch - 77ms/step
# Epoch 308/400
# 13/13 - 1s - loss: 0.0240 - mae: 0.1475 - val_loss: 0.5333 - val_mae: 1.0233 - 908ms/epoch - 70ms/step
# Epoch 309/400
# 13/13 - 1s - loss: 0.0242 - mae: 0.1519 - val_loss: 0.5302 - val_mae: 1.0199 - 1s/epoch - 83ms/step
# Epoch 310/400
# 13/13 - 1s - loss: 0.0268 - mae: 0.1597 - val_loss: 0.5272 - val_mae: 1.0167 - 972ms/epoch - 75ms/step
# Epoch 311/400
# 13/13 - 1s - loss: 0.0233 - mae: 0.1560 - val_loss: 0.5242 - val_mae: 1.0135 - 941ms/epoch - 72ms/step
# Epoch 312/400
# 13/13 - 1s - loss: 0.0297 - mae: 0.1697 - val_loss: 0.5208 - val_mae: 1.0098 - 1s/epoch - 89ms/step
# Epoch 313/400
# 13/13 - 1s - loss: 0.0270 - mae: 0.1646 - val_loss: 0.5175 - val_mae: 1.0062 - 1s/epoch - 86ms/step
# Epoch 314/400
# 13/13 - 1s - loss: 0.0291 - mae: 0.1742 - val_loss: 0.5150 - val_mae: 1.0035 - 1s/epoch - 81ms/step
# Epoch 315/400
# 13/13 - 1s - loss: 0.0305 - mae: 0.1788 - val_loss: 0.5119 - val_mae: 1.0001 - 925ms/epoch - 71ms/step
# Epoch 316/400
# 13/13 - 1s - loss: 0.0265 - mae: 0.1528 - val_loss: 0.5093 - val_mae: 0.9973 - 997ms/epoch - 77ms/step
# Epoch 317/400
# 13/13 - 1s - loss: 0.0223 - mae: 0.1526 - val_loss: 0.5057 - val_mae: 0.9935 - 1s/epoch - 95ms/step
# Epoch 318/400
# 13/13 - 1s - loss: 0.0277 - mae: 0.1675 - val_loss: 0.5027 - val_mae: 0.9901 - 1s/epoch - 96ms/step
# Epoch 319/400
# 13/13 - 1s - loss: 0.0242 - mae: 0.1571 - val_loss: 0.4995 - val_mae: 0.9867 - 1s/epoch - 79ms/step
# Epoch 320/400
# 13/13 - 1s - loss: 0.0300 - mae: 0.1723 - val_loss: 0.4970 - val_mae: 0.9839 - 1s/epoch - 77ms/step
# Epoch 321/400
# 13/13 - 1s - loss: 0.0271 - mae: 0.1648 - val_loss: 0.4941 - val_mae: 0.9807 - 975ms/epoch - 75ms/step
# Epoch 322/400
# 13/13 - 1s - loss: 0.0265 - mae: 0.1627 - val_loss: 0.4911 - val_mae: 0.9775 - 988ms/epoch - 76ms/step
# Epoch 323/400
# 13/13 - 1s - loss: 0.0254 - mae: 0.1582 - val_loss: 0.4884 - val_mae: 0.9745 - 1s/epoch - 81ms/step
# Epoch 324/400
# 13/13 - 1s - loss: 0.0211 - mae: 0.1489 - val_loss: 0.4861 - val_mae: 0.9720 - 1s/epoch - 88ms/step
# Epoch 325/400
# 13/13 - 1s - loss: 0.0269 - mae: 0.1675 - val_loss: 0.4836 - val_mae: 0.9692 - 964ms/epoch - 74ms/step
# Epoch 326/400
# 13/13 - 1s - loss: 0.0260 - mae: 0.1657 - val_loss: 0.4803 - val_mae: 0.9656 - 1s/epoch - 85ms/step
# Epoch 327/400
# 13/13 - 1s - loss: 0.0312 - mae: 0.1765 - val_loss: 0.4780 - val_mae: 0.9630 - 1s/epoch - 81ms/step
# Epoch 328/400
# 13/13 - 1s - loss: 0.0287 - mae: 0.1682 - val_loss: 0.4754 - val_mae: 0.9602 - 1s/epoch - 82ms/step
# Epoch 329/400
# 13/13 - 1s - loss: 0.0253 - mae: 0.1580 - val_loss: 0.4733 - val_mae: 0.9579 - 928ms/epoch - 71ms/step
# Epoch 330/400
# 13/13 - 1s - loss: 0.0231 - mae: 0.1530 - val_loss: 0.4697 - val_mae: 0.9538 - 1s/epoch - 88ms/step
# Epoch 331/400
# 13/13 - 1s - loss: 0.0258 - mae: 0.1576 - val_loss: 0.4668 - val_mae: 0.9507 - 950ms/epoch - 73ms/step
# Epoch 332/400
# 13/13 - 1s - loss: 0.0228 - mae: 0.1508 - val_loss: 0.4640 - val_mae: 0.9475 - 971ms/epoch - 75ms/step
# Epoch 333/400
# 13/13 - 1s - loss: 0.0234 - mae: 0.1513 - val_loss: 0.4612 - val_mae: 0.9445 - 967ms/epoch - 74ms/step
# Epoch 334/400
# 13/13 - 1s - loss: 0.0245 - mae: 0.1592 - val_loss: 0.4587 - val_mae: 0.9417 - 1s/epoch - 80ms/step
# Epoch 335/400
# 13/13 - 1s - loss: 0.0210 - mae: 0.1497 - val_loss: 0.4560 - val_mae: 0.9387 - 1s/epoch - 80ms/step
# Epoch 336/400
# 13/13 - 1s - loss: 0.0236 - mae: 0.1612 - val_loss: 0.4530 - val_mae: 0.9352 - 1s/epoch - 77ms/step
# Epoch 337/400
# 13/13 - 1s - loss: 0.0201 - mae: 0.1423 - val_loss: 0.4504 - val_mae: 0.9323 - 868ms/epoch - 67ms/step
# Epoch 338/400
# 13/13 - 1s - loss: 0.0212 - mae: 0.1456 - val_loss: 0.4479 - val_mae: 0.9295 - 1s/epoch - 82ms/step
# Epoch 339/400
# 13/13 - 1s - loss: 0.0302 - mae: 0.1774 - val_loss: 0.4452 - val_mae: 0.9265 - 924ms/epoch - 71ms/step
# Epoch 340/400
# 13/13 - 1s - loss: 0.0243 - mae: 0.1594 - val_loss: 0.4428 - val_mae: 0.9238 - 931ms/epoch - 72ms/step
# Epoch 341/400
# 13/13 - 1s - loss: 0.0248 - mae: 0.1640 - val_loss: 0.4408 - val_mae: 0.9215 - 932ms/epoch - 72ms/step
# Epoch 342/400
# 13/13 - 1s - loss: 0.0230 - mae: 0.1521 - val_loss: 0.4390 - val_mae: 0.9196 - 1s/epoch - 83ms/step
# Epoch 343/400
# 13/13 - 1s - loss: 0.0209 - mae: 0.1489 - val_loss: 0.4366 - val_mae: 0.9168 - 1s/epoch - 93ms/step
# Epoch 344/400
# 13/13 - 1s - loss: 0.0231 - mae: 0.1525 - val_loss: 0.4345 - val_mae: 0.9145 - 1s/epoch - 79ms/step
# Epoch 345/400
# 13/13 - 1s - loss: 0.0231 - mae: 0.1557 - val_loss: 0.4328 - val_mae: 0.9125 - 1s/epoch - 80ms/step
# Epoch 346/400
# 13/13 - 1s - loss: 0.0253 - mae: 0.1623 - val_loss: 0.4309 - val_mae: 0.9103 - 958ms/epoch - 74ms/step
# Epoch 347/400
# 13/13 - 1s - loss: 0.0226 - mae: 0.1446 - val_loss: 0.4284 - val_mae: 0.9075 - 1s/epoch - 103ms/step
# Epoch 348/400
# 13/13 - 1s - loss: 0.0236 - mae: 0.1582 - val_loss: 0.4261 - val_mae: 0.9049 - 940ms/epoch - 72ms/step
# Epoch 349/400
# 13/13 - 1s - loss: 0.0278 - mae: 0.1638 - val_loss: 0.4235 - val_mae: 0.9019 - 934ms/epoch - 72ms/step
# Epoch 350/400
# 13/13 - 1s - loss: 0.0229 - mae: 0.1524 - val_loss: 0.4210 - val_mae: 0.8991 - 925ms/epoch - 71ms/step
# Epoch 351/400
# 13/13 - 1s - loss: 0.0282 - mae: 0.1622 - val_loss: 0.4182 - val_mae: 0.8959 - 932ms/epoch - 72ms/step
# Epoch 352/400
# 13/13 - 1s - loss: 0.0239 - mae: 0.1584 - val_loss: 0.4157 - val_mae: 0.8930 - 1s/epoch - 86ms/step
# Epoch 353/400
# 13/13 - 1s - loss: 0.0179 - mae: 0.1390 - val_loss: 0.4132 - val_mae: 0.8901 - 1s/epoch - 93ms/step
# Epoch 354/400
# 13/13 - 1s - loss: 0.0213 - mae: 0.1471 - val_loss: 0.4110 - val_mae: 0.8877 - 961ms/epoch - 74ms/step
# Epoch 355/400
# 13/13 - 1s - loss: 0.0270 - mae: 0.1704 - val_loss: 0.4093 - val_mae: 0.8857 - 1s/epoch - 92ms/step
# Epoch 356/400
# 13/13 - 1s - loss: 0.0218 - mae: 0.1498 - val_loss: 0.4073 - val_mae: 0.8834 - 1s/epoch - 84ms/step
# Epoch 357/400
# 13/13 - 1s - loss: 0.0208 - mae: 0.1448 - val_loss: 0.4049 - val_mae: 0.8806 - 873ms/epoch - 67ms/step
# Epoch 358/400
# 13/13 - 1s - loss: 0.0220 - mae: 0.1546 - val_loss: 0.4031 - val_mae: 0.8785 - 1s/epoch - 79ms/step
# Epoch 359/400
# 13/13 - 1s - loss: 0.0219 - mae: 0.1532 - val_loss: 0.4018 - val_mae: 0.8771 - 931ms/epoch - 72ms/step
# Epoch 360/400
# 13/13 - 1s - loss: 0.0178 - mae: 0.1397 - val_loss: 0.4000 - val_mae: 0.8750 - 959ms/epoch - 74ms/step
# Epoch 361/400
# 13/13 - 1s - loss: 0.0209 - mae: 0.1511 - val_loss: 0.3986 - val_mae: 0.8734 - 1s/epoch - 83ms/step
# Epoch 362/400
# 13/13 - 1s - loss: 0.0200 - mae: 0.1450 - val_loss: 0.3969 - val_mae: 0.8715 - 951ms/epoch - 73ms/step
# Epoch 363/400
# 13/13 - 1s - loss: 0.0164 - mae: 0.1271 - val_loss: 0.3949 - val_mae: 0.8692 - 1s/epoch - 83ms/step
# Epoch 364/400
# 13/13 - 1s - loss: 0.0224 - mae: 0.1636 - val_loss: 0.3929 - val_mae: 0.8668 - 1s/epoch - 90ms/step
# Epoch 365/400
# 13/13 - 1s - loss: 0.0193 - mae: 0.1476 - val_loss: 0.3910 - val_mae: 0.8646 - 1s/epoch - 78ms/step
# Epoch 366/400
# 13/13 - 1s - loss: 0.0219 - mae: 0.1520 - val_loss: 0.3889 - val_mae: 0.8621 - 968ms/epoch - 74ms/step
# Epoch 367/400
# 13/13 - 1s - loss: 0.0241 - mae: 0.1563 - val_loss: 0.3876 - val_mae: 0.8606 - 1s/epoch - 93ms/step
# Epoch 368/400
# 13/13 - 1s - loss: 0.0240 - mae: 0.1582 - val_loss: 0.3854 - val_mae: 0.8581 - 950ms/epoch - 73ms/step
# Epoch 369/400
# 13/13 - 1s - loss: 0.0264 - mae: 0.1638 - val_loss: 0.3831 - val_mae: 0.8553 - 1s/epoch - 90ms/step
# Epoch 370/400
# 13/13 - 1s - loss: 0.0198 - mae: 0.1456 - val_loss: 0.3812 - val_mae: 0.8531 - 985ms/epoch - 76ms/step
# Epoch 371/400
# 13/13 - 1s - loss: 0.0205 - mae: 0.1477 - val_loss: 0.3797 - val_mae: 0.8514 - 1s/epoch - 96ms/step
# Epoch 372/400
# 13/13 - 1s - loss: 0.0214 - mae: 0.1510 - val_loss: 0.3779 - val_mae: 0.8492 - 932ms/epoch - 72ms/step
# Epoch 373/400
# 13/13 - 1s - loss: 0.0239 - mae: 0.1493 - val_loss: 0.3756 - val_mae: 0.8466 - 1s/epoch - 102ms/step
# Epoch 374/400
# 13/13 - 1s - loss: 0.0212 - mae: 0.1458 - val_loss: 0.3739 - val_mae: 0.8446 - 1s/epoch - 104ms/step
# Epoch 375/400
# 13/13 - 1s - loss: 0.0196 - mae: 0.1411 - val_loss: 0.3718 - val_mae: 0.8421 - 1s/epoch - 79ms/step
# Epoch 376/400
# 13/13 - 1s - loss: 0.0200 - mae: 0.1440 - val_loss: 0.3702 - val_mae: 0.8401 - 902ms/epoch - 69ms/step
# Epoch 377/400
# 13/13 - 1s - loss: 0.0211 - mae: 0.1494 - val_loss: 0.3688 - val_mae: 0.8385 - 947ms/epoch - 73ms/step
# Epoch 378/400
# 13/13 - 1s - loss: 0.0196 - mae: 0.1470 - val_loss: 0.3675 - val_mae: 0.8370 - 961ms/epoch - 74ms/step
# Epoch 379/400
# 13/13 - 1s - loss: 0.0190 - mae: 0.1478 - val_loss: 0.3661 - val_mae: 0.8353 - 924ms/epoch - 71ms/step
# Epoch 380/400
# 13/13 - 1s - loss: 0.0194 - mae: 0.1467 - val_loss: 0.3644 - val_mae: 0.8333 - 1s/epoch - 78ms/step
# Epoch 381/400
# 13/13 - 1s - loss: 0.0220 - mae: 0.1520 - val_loss: 0.3626 - val_mae: 0.8311 - 1s/epoch - 79ms/step
# Epoch 382/400
# 13/13 - 1s - loss: 0.0213 - mae: 0.1553 - val_loss: 0.3604 - val_mae: 0.8285 - 995ms/epoch - 77ms/step
# Epoch 383/400
# 13/13 - 1s - loss: 0.0183 - mae: 0.1414 - val_loss: 0.3584 - val_mae: 0.8261 - 1s/epoch - 88ms/step
# Epoch 384/400
# 13/13 - 1s - loss: 0.0212 - mae: 0.1523 - val_loss: 0.3565 - val_mae: 0.8239 - 996ms/epoch - 77ms/step
# Epoch 385/400
# 13/13 - 1s - loss: 0.0194 - mae: 0.1502 - val_loss: 0.3555 - val_mae: 0.8227 - 953ms/epoch - 73ms/step
# Epoch 386/400
# 13/13 - 1s - loss: 0.0227 - mae: 0.1591 - val_loss: 0.3542 - val_mae: 0.8212 - 979ms/epoch - 75ms/step
# Epoch 387/400
# 13/13 - 1s - loss: 0.0176 - mae: 0.1395 - val_loss: 0.3527 - val_mae: 0.8193 - 986ms/epoch - 76ms/step
# Epoch 388/400
# 13/13 - 1s - loss: 0.0220 - mae: 0.1475 - val_loss: 0.3510 - val_mae: 0.8173 - 1s/epoch - 90ms/step
# Epoch 389/400
# 13/13 - 1s - loss: 0.0252 - mae: 0.1690 - val_loss: 0.3497 - val_mae: 0.8157 - 1s/epoch - 81ms/step
# Epoch 390/400
# 13/13 - 1s - loss: 0.0188 - mae: 0.1472 - val_loss: 0.3479 - val_mae: 0.8136 - 922ms/epoch - 71ms/step
# Epoch 391/400
# 13/13 - 1s - loss: 0.0255 - mae: 0.1691 - val_loss: 0.3461 - val_mae: 0.8113 - 1s/epoch - 95ms/step
# Epoch 392/400
# 13/13 - 1s - loss: 0.0187 - mae: 0.1451 - val_loss: 0.3446 - val_mae: 0.8096 - 953ms/epoch - 73ms/step
# Epoch 393/400
# 13/13 - 1s - loss: 0.0167 - mae: 0.1304 - val_loss: 0.3429 - val_mae: 0.8076 - 903ms/epoch - 69ms/step
# Epoch 394/400
# 13/13 - 1s - loss: 0.0226 - mae: 0.1462 - val_loss: 0.3414 - val_mae: 0.8057 - 914ms/epoch - 70ms/step
# Epoch 395/400
# 13/13 - 1s - loss: 0.0194 - mae: 0.1507 - val_loss: 0.3406 - val_mae: 0.8048 - 962ms/epoch - 74ms/step
# Epoch 396/400
# 13/13 - 1s - loss: 0.0207 - mae: 0.1430 - val_loss: 0.3391 - val_mae: 0.8029 - 979ms/epoch - 75ms/step
# Epoch 397/400
# 13/13 - 1s - loss: 0.0188 - mae: 0.1489 - val_loss: 0.3377 - val_mae: 0.8012 - 1s/epoch - 78ms/step
# Epoch 398/400
# 13/13 - 1s - loss: 0.0194 - mae: 0.1469 - val_loss: 0.3365 - val_mae: 0.7998 - 988ms/epoch - 76ms/step
# Epoch 399/400
# 13/13 - 1s - loss: 0.0169 - mae: 0.1419 - val_loss: 0.3358 - val_mae: 0.7989 - 1s/epoch - 80ms/step
# Epoch 400/400
# 13/13 - 1s - loss: 0.0204 - mae: 0.1512 - val_loss: 0.3344 - val_mae: 0.7972 - 1s/epoch - 81ms/step

# %%
#Plot mae
plt.plot(history.history['mae'], label='Training mae')
plt.plot(history.history['val_mae'], label='Validation mae')
plt.legend()

# %%
#Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()

# %%
y_predict= model.predict(trainX)
y_predict2= model.predict(trainY)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 14, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 14, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 1).

# %%
import matplotlib.pyplot as plt
plt.plot(sorted_data_graph['ratio'].values, sorted_data_graph['date'].values)
plt.title('ACTUAL PM2.5')
plt.show()

plt.plot(range(0, len(trainX)), trainY, color='blue',
         label='actual')
plt.plot(range(0, len(trainX[:])), y_predict, color='red',
         label='prediction-train')

plt.plot(range(len(trainX),len(sorted_data_graph['ratio'].values)), trainY, color='blue')
plt.plot(range(len(trainX),len(sorted_data_graph['ratio'].values[:-10])), y_predict2, color='green',
         label='prediction-test')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e9f54c749597> in <module>()
#       9          label='prediction-train')
#      10
# ---> 11 plt.plot(range(len(trainX),len(sorted_data_graph['ratio'].values)), trainY, color='blue')
#      12 plt.plot(range(len(trainX),len(sorted_data_graph['ratio'].values[:-10])), y_predict2, color='green',
#      13          label='prediction-test')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (14,) and (248, 1)
